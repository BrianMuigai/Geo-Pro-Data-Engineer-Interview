# %%
import pandas as pd

# %%
test = pd.read_csv('../dataset/SECTION THREE DATA SET/test_resource_data_q2.csv')
test.head()
# Out:
#     time_spend  task_count  task_type
# 0     0.405813        3896         10
# 1   227.181065        2133          8
# 2  1265.799171         272          5
# 3   730.777326        1194         10
# 4     0.591428        2364          3

# %%
train = pd.read_csv('../dataset/SECTION THREE DATA SET/resource_dataset.csv')
train.head()
# Out:
#    physical_cores  logical_cores max_cpu_frequency min_cpu_frequency  \
# 0              12             12        2095.00Mhz           0.00Mhz
# 1              12             12        2095.00Mhz           0.00Mhz
# 2              12             12        2095.00Mhz           0.00Mhz
# 3              12             12        2095.00Mhz           0.00Mhz
# 4              12             12        2095.00Mhz           0.00Mhz
#
#   total_ram total_available_ram total_swap free_swap  start_time  stop_time  \
# 0  100.00GB             17.36GB   114.50GB   26.65GB    0.000018   0.000181
# 1  100.00GB             17.36GB   114.50GB   26.65GB    0.000187   0.000227
# 2  100.00GB             17.36GB   114.50GB   26.65GB    0.000229   0.000283
# 3  100.00GB             17.36GB   114.50GB   26.65GB    0.000020   0.000052
# 4  100.00GB             17.36GB   114.50GB   26.65GB    0.000054   0.000082
#
#    time_spend  task_count  task_type current_cpu_frequency
# ...
